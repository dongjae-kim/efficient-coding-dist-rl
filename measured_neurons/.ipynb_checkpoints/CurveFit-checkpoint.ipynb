# %%
# load
import scipy.io as sio
import numpy as np
from scipy.optimize import curve_fit
from scipy.stats.distributions import  t
import matplotlib.pyplot as plt


def func(x,a,b,c):
    return b / (1 + np.exp(-(x-c)*a))


juiceAmounts = [0.1, 0.3, 1.2, 2.5, 5, 10, 20];
dat = sio.loadmat('dat_eachneuron.mat')
dat = dat['dat']

ps = []
ps_ucb = []
ps_lcb = []

ps_total = []

for i in range(40):
    dats = dat[0,i][0]
    datas_x = []
    datas_y = []

    for count, j in enumerate(juiceAmounts):
        y_to_extend = np.squeeze(dats[np.where(~np.isnan(dats[:,count])),count])
        x_to_extend = (np.ones(y_to_extend.shape)*j).tolist()    
        datas_x.extend(x_to_extend)
        datas_y.extend(y_to_extend)
    
    x =datas_x
    y = datas_y


    initial_guess = [1, 1, 0]
    pars, pcov = curve_fit(func, x, y, p0=initial_guess, bounds = (0,np.inf))

#     alpha = 0.05 # 95% confidence interval = 100*(1-alpha)
    alpha = 0.1 # 90% confidence interval = 100*(1-alpha)

    n = len(y)    # number of data points
    p = len(pars) # number of parameters

    dof = max(0, n - p) # number of degrees of freedom

    # student-t value for the dof and confidence level
    tval = t.ppf(1.0-alpha/2., dof) 
    ps_ =[]
    ps_ucb_ =[]
    ps_lcb_ =[]
    for i, p,var in zip(range(n), pars, np.diag(pcov)):
        sigma = var**0.5
        ps_.append(p)
        ps_ucb_.append( p + sigma*tval)
        ps_lcb_.append( p - sigma*tval)
        
    
    ps.append(ps_)
    ps_ucb.append(ps_ucb_)
    ps_lcb.append(ps_lcb_)
    
    ps_total_ = []
    tts = np.linspace(-tval, tval, 121)
    for ttval in tts:
        ps_total_t = []
        #  40 neurons student t-test value linspace
        for i, p,var in zip(range(n), pars, np.diag(pcov)):
                sigma = var**0.5
                ps_total_t.append(p + sigma*ttval)

#                 if np.abs(sigma*ttval) < 0.0001:
#                     print(sigma*ttval)

        ps_total_.append(ps_total_t)
    
    ps_total.append(ps_total_)

# %%
alpha = 0.1 # 95% confidence interval = 100*(1-alpha)
tval = t.ppf(1.0-alpha/2., dof) 
tval
# Out:
# 1.650712726541289

# %%
sio.savemat('curve_fit_parameters_new.mat', {'ps':ps,'ps_ucb':ps_ucb,'ps_lcb':ps_lcb, 'ps_total':ps_total}) # post fix '_new' to prevent overwriting

# %%
# %matplotlib notebook
x_ = np.linspace(0,25,1000)
fig,ax = plt.subplots() 
for i in np.setdiff1d(np.linspace(0,39,40),19.).astype(np.int16):
    plt.plot(x_,func(x_, ps[i][0], ps[i][1], ps[i][2]))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
x_ = np.linspace(0,25,1000)
i = 2

fig,ax = plt.subplots(3,1)

for i in range(40):
    ax[0].plot(x_,func(x_, ps_lcb[i][0], ps_lcb[i][1],ps_lcb[i][2]),color=[0,0,0])
    ax[1].plot(x_,func(x_, ps[i][0], ps[i][1], ps[i][2]),color=[0,0,0])
    ax[2].plot(x_,func(x_, ps_ucb[i][0], ps_ucb[i][1],ps_ucb[i][2]),color=[0,0,0])
    
ax[0].set_ylim(0,25)
ax[1].set_ylim(0,25)
ax[2].set_ylim(0,25)
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ProgramData\Anaconda3\envs\base37\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in exp
#   # Remove the CWD from sys.path while we load stuff.
# (0.0, 25.0)

# %%
# %matplotlib notebook
x_ = np.linspace(0,25,1000)
i = 2


fig,ax = plt.subplots() 
for i in range(40):
    plt.plot(x_,func(x_, ps[i][0], ps[i][1], ps[i][2]),color=[0,0,0])
    y1 = func(x_, ps_lcb[i][0], ps_lcb[i][1],ps_lcb[i][2])
    y2 = func(x_, ps_ucb[i][0], ps_ucb[i][1],ps_ucb[i][2])
    plt.fill_between(x_, y1, y2,
                     facecolor=[.7,.7,.7], # The fill color
                     color=[0,0,0],       # The outline color
                     alpha=0.2)          # Transparency of the fill
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ProgramData\Anaconda3\envs\base37\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in exp
#   # Remove the CWD from sys.path while we load stuff.
